# %% [markdown]
# # Regression Week 5: LASSO (coordinate descent)

# %% [markdown]
# In this notebook, you will implement your very own LASSO solver via coordinate descent. You will:
# * Write a function to normalize features
# * Implement coordinate descent for LASSO
# * Explore effects of L1 penalty

# %% [markdown]
# # Fire up graphlab create

# %% [markdown]
# Make sure you have the latest version of graphlab (>= 1.7)

# %%
import graphlab
import numpy as np
# Out:
# A newer version of GraphLab Create (v1.8.4) is available! Your current version is v1.8.1.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %% [markdown]
# # Load in house sales data
#
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
sales = graphlab.SFrame('kc_house_data.gl/')
# In the dataset, 'floors' was defined with type string, 
# so we'll convert them to int, before using it below
sales['floors'] = sales['floors'].astype(int)
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to junchn8@gmail.com and will expire on December 23, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-4276 - Server binary: C:\Users\James\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\James\AppData\Local\Temp\graphlab_server_1457917504.log.0
# [INFO] GraphLab Server Version: 1.8.1

# %% [markdown]
# If we want to do any "feature engineering" like creating new features or adjusting existing ones we should do this directly using the SFrames as seen in the first notebook of Week 2. For this notebook, however, we will work with the existing features.

# %% [markdown]
# # Import useful functions from previous notebook

# %% [markdown]
# As in Week 2, we convert the SFrame into a 2D Numpy array. Copy and paste `get_num_data()` from the second notebook of Week 2.

# %%
import numpy as np # note this allows us to refer to numpy as np instead

# %%
def get_numpy_data(data_sframe, features, output):
    data_sframe['constant'] = 1 # this is how you add a constant column to an SFrame
    # add the column 'constant' to the front of the features list so that we can extract it along with the others:
    features = ['constant'] + features # this is how you combine two lists
    # select the columns of data_SFrame given by the features list into the SFrame features_sframe (now including constant):
    features_sframe = data_sframe[features]
    # the following line will convert the features_SFrame into a numpy matrix:
    feature_matrix = features_sframe.to_numpy()
    # assign the column of data_sframe associated with the output to the SArray output_sarray
    output_sarray = data_sframe[output]
    # the following will convert the SArray into a numpy array by first converting it to a list
    output_array = output_sarray.to_numpy()
    return(feature_matrix, output_array)

# %% [markdown]
# Also, copy and paste the `predict_output()` function to compute the predictions for an entire matrix of features given the matrix and the weights:

# %%
def predict_output(feature_matrix, weights):
    # assume feature_matrix is a numpy matrix containing the features as columns and weights is a corresponding numpy array
    # create the predictions vector by using np.dot()
    predictions = np.dot(feature_matrix,weights)

    return(predictions)

# %% [markdown]
# # Normalize features
# In the house dataset, features vary wildly in their relative magnitude: `sqft_living` is very large overall compared to `bedrooms`, for instance. As a result, weight for `sqft_living` would be much smaller than weight for `bedrooms`. This is problematic because "small" weights are dropped first as `l1_penalty` goes up.
#
# To give equal considerations for all features, we need to **normalize features** as discussed in the lectures: we divide each feature by its 2-norm so that the transformed feature has norm 1.
#
# Let's see how we can do this normalization easily with Numpy: let us first consider a small matrix.

# %%
X = np.array([[3.,5.,8.],[4.,12.,15.]])
print X
# Out:
# [[  3.   5.   8.]
#  [  4.  12.  15.]]

# %% [markdown]
# Numpy provides a shorthand for computing 2-norms of each column:

# %%
norms = np.linalg.norm(X, axis=0) # gives [norm(X[:,0]), norm(X[:,1]), norm(X[:,2])]
print norms
# Out:
# [  5.  13.  17.]

# %% [markdown]
# To normalize, apply element-wise division:

# %%
print X / norms # gives [X[:,0]/norm(X[:,0]), X[:,1]/norm(X[:,1]), X[:,2]/norm(X[:,2])]
# Out:
# [[ 0.6         0.38461538  0.47058824]
#  [ 0.8         0.92307692  0.88235294]]

# %% [markdown]
# Using the shorthand we just covered, write a short function called `normalize_features(feature_matrix)`, which normalizes columns of a given feature matrix. The function should return a pair `(normalized_features, norms)`, where the second item contains the norms of original features. As discussed in the lectures, we will use these norms to normalize the test data in the same way as we normalized the training data.

# %%
def normalize_features(feature_matrix):
    norms = np.linalg.norm(feature_matrix,axis=0)
    normalized_features = feature_matrix/norms
    return (normalized_features, norms)

# %% [markdown]
# To test the function, run the following:

# %%
features, norms = normalize_features(np.array([[3.,6.,9.],[4.,8.,12.]]))
print features
# should print
# [[ 0.6  0.6  0.6]
#  [ 0.8  0.8  0.8]]
print norms
# should print
# [5.  10.  15.]
# Out:
# [[ 0.6  0.6  0.6]
#  [ 0.8  0.8  0.8]]
# [  5.  10.  15.]

# %% [markdown]
# # Implementing Coordinate Descent with normalized features

# %% [markdown]
# We seek to obtain a sparse set of weights by minimizing the LASSO cost function
# ```
# SUM[ (prediction - output)^2 ] + lambda*( |w[1]| + ... + |w[k]|).
# ```
# (By convention, we do not include `w[0]` in the L1 penalty term. We never want to push the intercept to zero.)
#
# The absolute value sign makes the cost function non-differentiable, so simple gradient descent is not viable (you would need to implement a method called subgradient descent). Instead, we will use **coordinate descent**: at each iteration, we will fix all weights but weight `i` and find the value of weight `i` that minimizes the objective. That is, we look for
# ```
# argmin_{w[i]} [ SUM[ (prediction - output)^2 ] + lambda*( |w[1]| + ... + |w[k]|) ]
# ```
# where all weights other than `w[i]` are held to be constant. We will optimize one `w[i]` at a time, circling through the weights multiple times.
#   1. Pick a coordinate `i`
#   2. Compute `w[i]` that minimizes the cost function `SUM[ (prediction - output)^2 ] + lambda*( |w[1]| + ... + |w[k]|)`
#   3. Repeat Steps 1 and 2 for all coordinates, multiple times

# %% [markdown]
# For this notebook, we use **cyclical coordinate descent with normalized features**, where we cycle through coordinates 0 to (d-1) in order, and assume the features were normalized as discussed above. The formula for optimizing each coordinate is as follows:
# ```
#        ┌ (ro[i] + lambda/2)     if ro[i] < -lambda/2
# w[i] = ├ 0                      if -lambda/2 <= ro[i] <= lambda/2
#        └ (ro[i] - lambda/2)     if ro[i] > lambda/2
# ```
# where
# ```
# ro[i] = SUM[ [feature_i]*(output - prediction + w[i]*[feature_i]) ].
# ```
#
# Note that we do not regularize the weight of the constant feature (intercept) `w[0]`, so, for this weight, the update is simply:
# ```
# w[0] = ro[i]
# ```

# %% [markdown]
# ## Effect of L1 penalty

# %% [markdown]
# Let us consider a simple model with 2 features:

# %%
simple_features = ['sqft_living', 'bedrooms']
my_output = 'price'
(simple_feature_matrix, output) = get_numpy_data(sales, simple_features, my_output)

# %% [markdown]
# Don't forget to normalize features:

# %%
simple_feature_matrix, norms = normalize_features(simple_feature_matrix)

# %% [markdown]
# We assign some random set of initial weights and inspect the values of `ro[i]`:

# %%
weights = np.array([1., 4., 1.])

# %% [markdown]
# Use `predict_output()` to make predictions on this data.

# %%
prediction = predict_output(simple_feature_matrix,weights)
simple_feature_matrix.shape
#output.shape
# Out:
# (21613L, 3L)

# %% [markdown]
# Compute the values of `ro[i]` for each feature in this simple model, using the formula given above, using the formula:
# ```
# ro[i] = SUM[ [feature_i]*(output - prediction + w[i]*[feature_i]) ]
# ```
#
# *Hint: You can get a Numpy vector for feature_i using:*
# ```
# simple_feature_matrix[:,i]
# ```

# %%
ro = np.array([0., 0., 0.])

for i in range(0,3):
    feature_i=simple_feature_matrix[:,i]
    ro[i] = (feature_i*(output-prediction+weights[i]*feature_i)).sum()
  

print ro[0]
print ro[1]
print ro[2]
# Out:
# 79400300.0349
# 87939470.773
# 80966698.676

# %% [markdown]
# ***QUIZ QUESTION***
#
# Recall that, whenever `ro[i]` falls between `-l1_penalty/2` and `l1_penalty/2`, the corresponding weight `w[i]` is sent to zero. Now suppose we were to take one step of coordinate descent on either feature 1 or feature 2. What range of values of `l1_penalty` **would not** set `w[1]` zero, but **would** set `w[2]` to zero, if we were to take a step in that coordinate?

# %%
=2*87.9x10^6
# Out:
#   File "<ipython-input-16-cb3b96d765a5>", line 1
#     =2*87.9x10^6
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ***QUIZ QUESTION***
#
# What range of values of `l1_penalty` would set **both** `w[1]` and `w[2]` to zero, if we were to take a step in that coordinate?

# %%
2*80.9x10^6
# Out:
#   File "<ipython-input-17-3edb90505205>", line 1
#     2*80.9x10^6
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# So we can say that `ro[i]` quantifies the significance of the i-th feature: the larger `ro[i]` is, the more likely it is for the i-th feature to be retained.

# %% [markdown]
# ## Single Coordinate Descent Step

# %% [markdown]
# Using the formula above, implement coordinate descent that minimizes the cost function over a single feature i. Note that the intercept (weight 0) is not regularized. The function should accept feature matrix, output, current weights, l1 penalty, and index of feature to optimize over. The function should return new weight for feature i.

# %%
def lasso_coordinate_descent_step(i, feature_matrix, output, weights, l1_penalty):
    # compute prediction
    prediction = predict_output(feature_matrix,weights)
    # compute ro[i] = SUM[ [feature_i]*(output - prediction + weight[i]*[feature_i]) ]
    feature_i=feature_matrix[:,i]
    ro_i = (feature_i*(output-prediction+weights[i]*feature_i)).sum()

    if i == 0: # intercept -- do not regularize
        new_weight_i = ro_i 
    elif ro_i < -l1_penalty/2.:
        new_weight_i = (ro_i + l1_penalty/2)
    elif ro_i > l1_penalty/2.:
        new_weight_i = (ro_i - l1_penalty/2)
    else:
        new_weight_i = 0.
    
    return new_weight_i

# %% [markdown]
# To test the function, run the following cell:

# %%
# should print 0.425558846691
import math
print lasso_coordinate_descent_step(1, np.array([[3./math.sqrt(13),1./math.sqrt(10)],[2./math.sqrt(13),3./math.sqrt(10)]]), 
                                   np.array([1., 1.]), np.array([1., 4.]), 0.1)
# Out:
# 0.425558846691

# %%
def lasso_cyclical_coordinate_descent(normalized_simple_feature_matrix, output,initial_weights, l1_penalty, tolerance):
    count=0.0
    weight_check_new =0.0
    while (count<400):
        for i in range(len(initial_weights)):
            weights_test2 = np.zeros(len(initial_weights))
            weights_test2[i]= lasso_coordinate_descent_step(i, normalized_simple_feature_matrix, output, initial_weights, l1_penalty)
            a_weight = abs(weights_test2[i] - initial_weights[i])
            

            initial_weights[i]=weights_test2[i]
            if (a_weight >= weight_check_new):
                weight_check_new = a_weight

        if(weight_check_new < tolerance):
            break
        weigth_check_new=0.        

        count=count+1
    return weights_test2

# %% [markdown]
# ## Cyclical coordinate descent

# %% [markdown]
# Now that we have a function that optimizes the cost function over a single coordinate, let us implement cyclical coordinate descent where we optimize coordinates 0, 1, ..., (d-1) in order and repeat.
#
# When do we know to stop? Each time we scan all the coordinates (features) once, we measure the change in weight for each coordinate. If no coordinate changes by more than a specified threshold, we stop.

# %% [markdown]
# For each iteration:
# 1. As you loop over features in order and perform coordinate descent, measure how much each coordinate changes.
# 2. After the loop, if the maximum change across all coordinates is falls below the tolerance, stop. Otherwise, go back to step 1.
#
# Return weights
#
# **IMPORTANT: when computing a new weight for coordinate i, make sure to incorporate the new weights for coordinates 0, 1, ..., i-1. One good way is to update your weights variable in-place. See following pseudocode for illustration.**
# ```
# for i in range(len(weights)):
#     old_weights_i = weights[i] # remember old value of weight[i], as it will be overwritten
#     # the following line uses new values for weight[0], weight[1], ..., weight[i-1]
#     #     and old values for weight[i], ..., weight[d-1]
#     weights[i] = lasso_coordinate_descent_step(i, feature_matrix, output, weights, l1_penalty)
#
#     # use old_weights_i to compute change in coordinate
#     ...
# ```
#
# argmin_{w[i]} [ SUM[ (prediction - output)^2 ] + lambda*( |w[1]| + ... + |w[k]|) ]

# %%
old_weights = np.zeros(14)
l1_penalty = 1e7
tolerance = 1.0
all_features = ['bedrooms',
                'bathrooms',
                'sqft_living',
                'sqft_lot',
                'floors',
                'waterfront', 
                'view', 
                'condition', 
                'grade',
                'sqft_above',
                'sqft_basement',
                'yr_built', 
                'yr_renovated']
initial_weights2=np.zeros(14)

my_output = 'price'
(all_feature_matrix, output) = get_numpy_data(sales, all_features, my_output)
all_feature_matrix, norms = normalize_features(all_feature_matrix)

count=0
weight_check_new =0.0
while (count<200):
    for i in range(len(old_weights)):
        weights_test2 = np.zeros(len(old_weights))
        weights_test2[i]= lasso_coordinate_descent_step(i, all_feature_matrix, output, initial_weights2, l1_penalty)
#        print 'weights_test2[',i,']', weights_test2[i],'initials weights[',i,']',initial_weights2[i]
        a_weight = abs(weights_test2[i] - initial_weights2[i])
#        print 'weights_test2[',i,'] - initial_weights2[',i,']', a_weight
        print 'a weight',a_weight
        initial_weights2[i]=weights_test2[i]
#        print initial_weights2
        if (a_weight >= weight_check_new):
            weight_check_new = a_weight
        print 'weight check new',weight_check_new
    if(weight_check_new < tolerance):
        print 'we need to break'
        break
    weigth_check_new=0.        
#        print 'weight check new',weight_check_new
#    print 'pass1 weights 2',weights_test2
    count=count+1
    #initial_weights2 = np.zeros(len(old_weights))
    #initial_weights2=weights_test2
    
#    print 'pass1 iniital weights',initial_weights2
#    print ''
# Out:
# a weight 79400304.6581
# weight check new 79400304.6581
# a weight 0.0
# weight check new 79400304.6581
# a weight 4698536.82948
# weight check new 79400304.6581
# a weight 5776463.78714
# weight check new 79400304.6581
# a weight 0.0
# weight check new 79400304.6581
# a weight 88695.2901831
# weight check new 79400304.6581
# a weight 8144113.54472
# weight check new 79400304.6581
# a weight 8445943.30497
# weight check new 79400304.6581
# a weight 7231648.05717
# weight check new 79400304.6581
# a weight 0.0
# weight check new 79400304.6581
# a weight 1349249.7756
# weight check new 79400304.6581
# a weight 2364615.54323
# weight check new 79400304.6581
# a weight 3190664.53549
# weight check new 79400304.6581
# a weight 0.0
# weight check new 79400304.6581
# a weight 5024423.98927
# weight check new 5024423.98927
# a weight 0.0
# weight check new 5024423.98927
# a weight 2481113.24532
# weight check new 5024423.98927
# a weight 4642999.41444
# weight check new 5024423.98927
# a weight 0.0
# weight check new 5024423.98927
# a weight 88695.2901831
# weight check new 5024423.98927
# a weight 3341952.83139
# weight check new 5024423.98927
# a weight 1936828.77126
# weight check new 5024423.98927
# a weight 1240009.3333
# weight check new 5024423.98927
# a weight 0.0
# weight check new 5024423.98927
# a weight 148172.590528
# weight check new 5024423.98927
# a weight 249081.003721
# weight check new 5024423.98927
# a weight 983174.586463
# weight check new 5024423.98927
# a weight 0.0
# weight check new 5024423.98927
# a weight 5008022.34861
# weight check new 5008022.34861
# a weight 0.0
# weight check new 5008022.34861
# a weight 1612070.78177
# weight check new 5008022.34861
# a weight 4324175.8628
# weight check new 5008022.34861
# a weight 0.0
# weight check new 5008022.34861
# a weight 0.0
# weight check new 5008022.34861
# a weight 896647.032543
# weight check new 5008022.34861
# a weight 165006.836955
# weight check new 5008022.34861
# a weight 301508.931933
# weight check new 5008022.34861
# a weight 0.0
# weight check new 5008022.34861
# a weight 669103.842118
# weight check new 5008022.34861
# a weight 289981.296082
# weight check new 5008022.34861
# a weight 26659.790468
# weight check new 5008022.34861
# a weight 0.0
# weight check new 5008022.34861
# a weight 4996955.12034
# weight check new 4996955.12034
# a weight 0.0
# weight check new 4996955.12034
# a weight 1073377.82483
# weight check new 4996955.12034
# a weight 4132393.27447
# weight check new 4996955.12034
# a weight 0.0
# weight check new 4996955.12034
# a weight 0.0
# weight check new 4996955.12034
# a weight 168006.635573
# weight check new 4996955.12034
# a weight 154294.645825
# weight check new 4996955.12034
# a weight 1018369.61251
# weight check new 4996955.12034
# a weight 0.0
# weight check new 4996955.12034
# a weight 828318.524006
# weight check new 4996955.12034
# a weight 695037.592007
# weight check new 4996955.12034
# a weight 392661.416994
# weight check new 4996955.12034
# a weight 0.0
# weight check new 4996955.12034
# a weight 4988079.04818
# weight check new 4988079.04818
# a weight 0.0
# weight check new 4988079.04818
# a weight 674890.561603
# weight check new 4988079.04818
# a weight 3983240.89936
# weight check new 4988079.04818
# a weight 0.0
# weight check new 4988079.04818
# a weight 0.0
# weight check new 4988079.04818
# a weight 10332.8583992
# weight check new 4988079.04818
# a weight 141822.813556
# weight check new 4988079.04818
# a weight 1500713.38228
# weight check new 4988079.04818
# a weight 0.0
# weight check new 4988079.04818
# a weight 0.0
# weight check new 4988079.04818
# a weight 1260402.77633
# weight check new 4988079.04818
# a weight 38348.7586652
# weight check new 4988079.04818
# a weight 0.0
# weight check new 4988079.04818
# a weight 4978035.04736
# weight check new 4978035.04736
# a weight 0.0
# weight check new 4978035.04736
# a weight 303636.19149
# weight check new 4978035.04736
# a weight 3828490.7477
# weight check new 4978035.04736
# a weight 0.0
# weight check new 4978035.04736
# a weight 0.0
# weight check new 4978035.04736
# a weight 10084.6480691
# weight check new 4978035.04736
# a weight 46310.1258848
# weight check new 4978035.04736
# a weight 1954639.74073
# weight check new 4978035.04736
# a weight 0.0
# weight check new 4978035.04736
# a weight 0.0
# weight check new 4978035.04736
# a weight 368274.882533
# weight check new 4978035.04736
# a weight 520978.371785
# weight check new 4978035.04736
# a weight 0.0
# weight check new 4978035.04736
# a weight 4971369.55739
# weight check new 4971369.55739
# a weight 0.0
# weight check new 4971369.55739
# a weight 81775.3428927
# weight check new 4971369.55739
# a weight 3612027.97306
# weight check new 4971369.55739
# a weight 0.0
# weight check new 4971369.55739
# a weight 0.0
# weight check new 4971369.55739
# a weight 64264.3486646
# weight check new 4971369.55739
# a weight 140827.753315
# weight check new 4971369.55739
# a weight 2495945.73185
# weight check new 4971369.55739
# a weight 0.0
# weight check new 4971369.55739
# a weight 0.0
# weight check new 4971369.55739
# a weight 0.0
# weight check new 4971369.55739
# a weight 665195.178608
# weight check new 4971369.55739
# a weight 0.0
# weight check new 4971369.55739
# a weight 4967200.91813
# weight check new 4967200.91813
# a weight 0.0
# weight check new 4967200.91813
# a weight 417206.993651
# weight check new 4967200.91813
# a weight 3385049.9375
# weight check new 4967200.91813
# a weight 0.0
# weight check new 4967200.91813
# a weight 0.0
# weight check new 4967200.91813
# a weight 41542.0247785
# weight check new 4967200.91813
# a weight 211456.365459
# weight check new 4967200.91813
# a weight 1200479.99117
# weight check new 4967200.91813
# a weight 0.0
# weight check new 4967200.91813
# a weight 0.0
# weight check new 4967200.91813
# a weight 0.0
# weight check new 4967200.91813
# a weight 1144374.27972
# weight check new 4967200.91813
# a weight 0.0
# weight check new 4967200.91813
# a weight 4962577.51514
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 700895.058285
# weight check new 4962577.51514
# a weight 3177811.03355
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 566.839536816
# weight check new 4962577.51514
# a weight 200869.707807
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 2768192.45246
# weight check new 4962577.51514
# a weight 0.0
# weight check new 4962577.51514
# a weight 4957534.13589
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 945102.705341
# weight check new 4957534.13589
# a weight 2984599.73874
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 9096.19175166
# weight check new 4957534.13589
# a weight 170088.581975
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 1066473.49137
# weight check new 4957534.13589
# a weight 0.0
# weight check new 4957534.13589
# a weight 2859631.87505
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 1138270.58885
# weight check new 2859631.87505
# a weight 2798662.56945
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 3946.72669744
# weight check new 2859631.87505
# a weight 150064.388029
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 0.0
# weight check new 2859631.87505
# a weight 1447085.6657
# weight check new 1447085.6657
# a weight 0.0
# weight check new 1447085.6657
# a weight 1287790.30439
# weight check new 1447085.6657
# a weight 2621198.42689
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 2255.91254875
# weight check new 2621198.42689
# a weight 134167.12605
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 0.0
# weight check new 2621198.42689
# a weight 1148752.34145
# weight check new 1148752.34145
# a weight 0.0
# weight check new 1148752.34145
# a weight 1402229.96742
# weight check new 1402229.96742
# a weight 2452797.88937
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 2096.6069004
# weight check new 2452797.88937
# a weight 119303.492567
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 0.0
# weight check new 2452797.88937
# a weight 891503.318023
# weight check new 891503.318023
# a weight 0.0
# weight check new 891503.318023
# a weight 1486612.51378
# weight check new 1486612.51378
# a weight 2293213.86438
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 1752.59395348
# weight check new 2293213.86438
# a weight 105783.663061
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 0.0
# weight check new 2293213.86438
# a weight 670153.120227
# weight check new 670153.120227
# a weight 0.0
# weight check new 670153.120227
# a weight 1545290.5946
# weight check new 1545290.5946
# a weight 2142223.26946
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 1376.9794398
# weight check new 2142223.26946
# a weight 93638.8896869
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 0.0
# weight check new 2142223.26946
# a weight 480411.951049
# weight check new 480411.951049
# a weight 0.0
# weight check new 480411.951049
# a weight 1582085.32384
# weight check new 1582085.32384
# a weight 1999578.16823
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 1034.87494104
# weight check new 1999578.16823
# a weight 82771.9201527
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 0.0
# weight check new 1999578.16823
# a weight 318496.658462
# weight check new 318496.658462
# a weight 0.0
# weight check new 318496.658462
# a weight 256366.041433
# weight check new 318496.658462
# a weight 569574.907794
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 18895.933126
# weight check new 569574.907794
# a weight 43371.7157643
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 0.0
# weight check new 569574.907794
# a weight 269108.569215
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 260255.365816
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 9527.80544753
# weight check new 269108.569215
# a weight 23429.1988831
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 0.0
# weight check new 269108.569215
# a weight 232054.526882
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 219967.746966
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 3052.3567506
# weight check new 232054.526882
# a weight 16414.7394161
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 0.0
# weight check new 232054.526882
# a weight 196688.671035
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 185753.136996
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 1265.0372289
# weight check new 196688.671035
# a weight 13112.6092634
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 0.0
# weight check new 196688.671035
# a weight 166199.972171
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 156832.893731
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 774.984704163
# weight check new 166199.972171
# a weight 10912.2152292
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 0.0
# weight check new 166199.972171
# a weight 140344.99571
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 132410.07437
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 591.926840115
# weight check new 140344.99571
# a weight 9179.68838594
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 0.0
# weight check new 140344.99571
# a weight 118494.053052
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 111789.45465
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 486.687017489
# weight check new 118494.053052
# a weight 7743.19664179
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 0.0
# weight check new 118494.053052
# a weight 100041.504132
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 94379.9318243
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 408.175374823
# weight check new 100041.504132
# a weight 6535.87534017
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 0.0
# weight check new 100041.504132
# a weight 84461.7311809
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 79681.6355572
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 344.043655448
# weight check new 84461.7311809
# a weight 5517.71039002
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 0.0
# weight check new 84461.7311809
# a weight 71308.0879055
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 67272.3751496
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 290.346723005
# weight check new 71308.0879055
# a weight 4658.34514924
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 0.0
# weight check new 71308.0879055
# a weight 60202.8941328
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 56795.6753808
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 245.10512149
# weight check new 60202.8941328
# a weight 3932.86242922
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 0.0
# weight check new 60202.8941328
# a weight 50827.1654552
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 47950.5697292
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 206.928500695
# weight check new 50827.1654552
# a weight 3320.37328363
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 0.0
# weight check new 50827.1654552
# a weight 42911.5693095
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 40482.9613751
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 174.701331289
# weight check new 42911.5693095
# a weight 2803.27257234
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 0.0
# weight check new 42911.5693095
# a weight 36228.7125282
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 34178.325099
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 147.49390641
# weight check new 36228.7125282
# a weight 2366.70326067
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 0.0
# weight check new 36228.7125282
# a weight 30586.6140529
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 28855.5448206
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 124.523816697
# weight check new 30586.6140529
# a weight 1998.1234015
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 0.0
# weight check new 30586.6140529
# a weight 25823.1908749
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 24361.710659
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 105.131022207
# weight check new 25823.1908749
# a weight 1686.94454839
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 0.0
# weight check new 25823.1908749
# a weight 21801.6020254
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 20567.7262348
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 88.7583826352
# weight check new 21801.6020254
# a weight 1424.22730922
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 0.0
# weight check new 21801.6020254
# a weight 18406.3175291
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 17364.600064
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 74.9355466422
# weight check new 18406.3175291
# a weight 1202.42448476
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 0.0
# weight check new 18406.3175291
# a weight 15539.7995333
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 14660.3145113
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 63.2654179372
# weight check new 15539.7995333
# a weight 1015.16424547
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 0.0
# weight check new 15539.7995333
# a weight 13119.7002961
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 12377.1823582
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 53.4127432201
# weight check new 13119.7002961
# a weight 857.067082692
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 0.0
# weight check new 13119.7002961
# a weight 11076.4965461
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 10449.6150482
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 45.0944802407
# weight check new 11076.4965461
# a weight 723.591268625
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 0.0
# weight check new 11076.4965461
# a weight 9351.49225725
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 8822.23849458
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 38.0716665294
# weight check new 9351.49225725
# a weight 610.902383965
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 0.0
# weight check new 9351.49225725
# a weight 7895.13246119
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 7448.30232468
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 32.1425545793
# weight check new 7895.13246119
# a weight 515.763164803
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 0.0
# weight check new 7895.13246119
# a weight 6665.5796599
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 6288.33686074
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 27.1368161403
# weight check new 6665.5796599
# a weight 435.440504327
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 0.0
# weight check new 6665.5796599
# a weight 5627.51194117
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 5309.01925707
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 22.9106491357
# weight check new 5627.51194117
# a weight 367.626937609
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 0.0
# weight check new 5627.51194117
# a weight 4751.10827023
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 4482.21621966
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 19.3426465765
# weight check new 4751.10827023
# a weight 310.37435405
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 0.0
# weight check new 4751.10827023
# a weight 4011.19180758
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 3784.17580858
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 16.330308862
# weight check new 4011.19180758
# a weight 262.038033117
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 0.0
# weight check new 4011.19180758
# a weight 3386.50664267
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 3194.84510528
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 13.7870992199
# weight check new 3386.50664267
# a weight 221.22939574
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 0.0
# weight check new 3386.50664267
# a weight 2859.1071659
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 2697.29414356
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 11.6399577316
# weight check new 2859.1071659
# a weight 186.776113966
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 0.0
# weight check new 2859.1071659
# a weight 2413.84253705
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 2277.22955485
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 9.82720250078
# weight check new 2413.84253705
# a weight 157.688433016
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 0.0
# weight check new 2413.84253705
# a weight 2037.92144036
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 1922.58395617
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 8.29675770923
# weight check new 2037.92144036
# a weight 133.130738068
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 0.0
# weight check new 2037.92144036
# a weight 1720.54462267
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 1623.1692851
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 7.00465758145
# weight check new 1720.54462267
# a weight 112.397549268
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 0.0
# weight check new 1720.54462267
# a weight 1452.59465845
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 1370.38412269
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 5.91378337145
# weight check new 1452.59465845
# a weight 94.8932550419
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 0.0
# weight check new 1452.59465845
# a weight 1226.37402945
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 1156.96659674
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 4.99279706553
# weight check new 1226.37402945
# a weight 80.1150017139
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 0.0
# weight check new 1226.37402945
# a weight 1035.38399467
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 976.785766706
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 4.21524106525
# weight check new 1035.38399467
# a weight 67.6382478047
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 0.0
# weight check new 1035.38399467
# a weight 874.137898121
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 824.665497467
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 3.55877817422
# weight check new 874.137898121
# a weight 57.1045680381
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 0.0
# weight check new 874.137898121
# a weight 738.003551215
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 696.235762119
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 3.00454989821
# weight check new 738.003551215
# a weight 48.211356692
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 0.0
# weight check new 738.003551215
# a weight 623.07016179
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 587.807102323
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 2.53663466685
# weight check new 623.07016179
# a weight 40.7031345088
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 0.0
# weight check new 623.07016179
# a weight 526.035987046
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 496.264639579
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 2.14159046486
# weight check new 526.035987046
# a weight 34.3642094471
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 0.0
# weight check new 526.035987046
# a weight 444.113482952
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 418.978592657
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 1.80806869827
# weight check new 444.113482952
# a weight 29.0124803595
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 0.0
# weight check new 444.113482952
# a weight 374.949225128
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 353.728730813
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 1.52648812532
# weight check new 374.949225128
# a weight 24.494205758
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 0.0
# weight check new 374.949225128
# a weight 316.556301083
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 298.64059215
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 1.28875965253
# weight check new 316.556301083
# a weight 20.6795871407
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 0.0
# weight check new 316.556301083
# a weight 267.257231228
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 252.131635077
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 1.08805396222
# weight check new 267.257231228
# a weight 17.4590402432
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 0.0
# weight check new 267.257231228
# a weight 225.635779154
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 212.865776062
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.918605273589
# weight check new 225.635779154
# a weight 14.7400470003
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 0.0
# weight check new 225.635779154
# a weight 190.496266846
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 179.715007208
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.775545779616
# weight check new 190.496266846
# a weight 12.4444976635
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 0.0
# weight check new 190.496266846
# a weight 160.829225831
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 151.726991601
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.654765730724
# weight check new 160.829225831
# a weight 10.5064469706
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 0.0
# weight check new 160.829225831
# a weight 135.782397784
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 128.097705022
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.552795428783
# weight check new 135.782397784
# a weight 8.87021966465
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 0.0
# weight check new 135.782397784
# a weight 114.636251304
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 108.148338392
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.466705529019
# weight check new 114.636251304
# a weight 7.48881112039
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 0.0
# weight check new 114.636251304
# a weight 96.7833115794
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 91.3057973534
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.394022887573
# weight check new 96.7833115794
# a weight 6.32253699563
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 0.0
# weight check new 96.7833115794
# a weight 81.7107092552
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 77.086238727
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.332659512758
# weight check new 81.7107092552
# a weight 5.33789321594
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 0.0
# weight check new 81.7107092552
# a weight 68.985446956
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 65.0811709017
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.280852600932
# weight check new 68.985446956
# a weight 4.50659347884
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 0.0
# weight check new 68.985446956
# a weight 58.2419603877
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 54.9457189068
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.237113868818
# weight check new 58.2419603877
# a weight 3.80475665815
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 0.0
# weight check new 58.2419603877
# a weight 49.1716166213
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 46.3887171224
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.2001868058
# weight check new 49.1716166213
# a weight 3.212220788
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 0.0
# weight check new 49.1716166213
# a weight 41.5138478242
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 39.1643447131
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.169010607526
# weight check new 41.5138478242
# a weight 2.71196381375
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 0.0
# weight check new 41.5138478242
# a weight 35.0486658774
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 33.0650639236
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.14268964529
# weight check new 35.0486658774
# a weight 2.28961463645
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 0.0
# weight check new 35.0486658774
# a weight 29.5903425962
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 27.9156579822
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.120467796922
# weight check new 29.5903425962
# a weight 1.93304023705
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 0.0
# weight check new 29.5903425962
# a weight 24.9820742942
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 23.5681976154
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.101706676185
# weight check new 24.9820742942
# a weight 1.63199715316
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 0.0
# weight check new 24.9820742942
# a weight 21.0914771967
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 19.8977913782
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0858673304319
# weight check new 21.0914771967
# a weight 1.3778371755
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 0.0
# weight check new 21.0914771967
# a weight 17.8067843802
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 16.7989978939
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0724947359413
# weight check new 17.8067843802
# a weight 1.16325895116
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 0.0
# weight check new 17.8067843802
# a weight 15.0336350165
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 14.1827967018
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0612047277391
# weight check new 15.0336350165
# a weight 0.98209817335
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 0.0
# weight check new 15.0336350165
# a weight 12.69236359
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 11.974031046
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.051672976464
# weight check new 12.69236359
# a weight 0.829150576144
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 0.0
# weight check new 12.69236359
# a weight 10.7157113515
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 10.1092487201
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0436256565154
# weight check new 10.7157113515
# a weight 0.700022349134
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 0.0
# weight check new 10.7157113515
# a weight 9.04689414427
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 8.53487931192
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0368315912783
# weight check new 9.04689414427
# a weight 0.591003986076
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 0.0
# weight check new 9.04689414427
# a weight 7.63797110319
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 7.20569517463
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0310956016183
# weight check new 7.63797110319
# a weight 0.498963650316
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 0.0
# weight check new 7.63797110319
# a weight 6.44846746325
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 6.08351227641
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0262529104948
# weight check new 6.44846746325
# a weight 0.421257279813
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 0.0
# weight check new 6.44846746325
# a weight 5.4442118369
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 5.13609313965
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0221644025296
# weight check new 5.4442118369
# a weight 0.355652540922
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 0.0
# weight check new 5.4442118369
# a weight 4.59635450691
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 4.33622085303
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0187126155943
# weight check new 4.59635450691
# a weight 0.300264799967
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 0.0
# weight check new 4.59635450691
# a weight 3.88053871319
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 3.66091710329
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0157983954996
# weight check new 3.88053871319
# a weight 0.25350289233
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 0.0
# weight check new 3.88053871319
# a weight 3.27620087564
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 3.09078216553
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0133380237967
# weight check new 3.27620087564
# a weight 0.214023482054
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 0.0
# weight check new 3.27620087564
# a weight 2.76597993076
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 2.60943750292
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0112608186901
# weight check new 2.76597993076
# a weight 0.180692415684
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 0.0
# weight check new 2.76597993076
# a weight 2.33521851897
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 2.20305532217
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.00950711034238
# weight check new 2.33521851897
# a weight 0.15255218558
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 0.0
# weight check new 2.33521851897
# a weight 1.97154198214
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 1.85996127874
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.00802651420236
# weight check new 1.97154198214
# a weight 0.128794381395
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 0.0
# weight check new 1.97154198214
# a weight 1.66450280324
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 1.57029918581
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.00677649863064
# weight check new 1.66450280324
# a weight 0.108736520633
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 0.0
# weight check new 1.66450280324
# a weight 1.4052805379
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 1.32574778795
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.00572115927935
# weight check new 1.4052805379
# a weight 0.0918023828417
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 0.0
# weight check new 1.4052805379
# a weight 1.1864284128
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 1.1192817241
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.00483017228544
# weight check new 1.1864284128
# a weight 0.0775054842234
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 0.0
# weight check new 1.1864284128
# a weight 1.00165932253
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.944969758391
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.00407794304192
# weight check new 1.00165932253
# a weight 0.0654351245612
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.0
# weight check new 1.00165932253
# a weight 0.845665354282
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.797804377973
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.00344286113977
# weight check new 0.845665354282
# a weight 0.0552445482463
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# a weight 0.0
# weight check new 0.845665354282
# we need to break

# %% [markdown]
# Using the following parameters, learn the weights on the sales dataset.

# %%
lasso_simple_features = ['sqft_living', 'bedrooms']
my_output = 'price'
(lasso_feature_matrix, output) = get_numpy_data(sales, lasso_simple_features, my_output)
lasso_feature_matrix, norms = normalize_features(lasso_feature_matrix)

initial_weights = np.zeros(3)
l1_penalty = 1e7
tolerance = 1.0
weights_test = np.zeros(3)
i=0
weights_test[i]= lasso_coordinate_descent_step(i, lasso_feature_matrix, output, initial_weights, l1_penalty)

# %% [markdown]
# First create a normalized version of the feature matrix, `normalized_simple_feature_matrix`

# %%
(simple_feature_matrix, output) = get_numpy_data(sales, simple_features, my_output)
(normalized_simple_feature_matrix, simple_norms) = normalize_features(simple_feature_matrix) # normalize features

# %% [markdown]
# Then, run your implementation of LASSO coordinate descent:

# %%
weights = lasso_cyclical_coordinate_descent(normalized_simple_feature_matrix, output,
                                            initial_weights, l1_penalty, tolerance)
prediction = predict_output(simple_feature_matrix,weights)
error = prediction - output
RSS = (error*error).sum()
print RSS
print weights
# Out:
# 7.71204784862e+26
# [ 79400304.65805088  82939472.63156717  75966703.41511109]

# %% [markdown]
# ***QUIZ QUESTIONS***
# 1. What is the RSS of the learned model on the normalized dataset?
# 2. Which features had weight zero at convergence?
# bedroom

# %% [markdown]
# # Evaluating LASSO fit with more features

# %% [markdown]
# Let us split the sales dataset into training and test sets.

# %%
train_data,test_data = sales.random_split(.8,seed=0)

# %% [markdown]
# Let us consider the following set of features.

# %%
all_features = ['bedrooms',
                'bathrooms',
                'sqft_living',
                'sqft_lot',
                'floors',
                'waterfront', 
                'view', 
                'condition', 
                'grade',
                'sqft_above',
                'sqft_basement',
                'yr_built', 
                'yr_renovated']

# %% [markdown]
# First, create a normalized feature matrix from the TRAINING data with these features.  (Make you store the norms for the normalization, since we'll use them later)

# %%
my_output = 'price'
(simple_feature_matrix, output) = get_numpy_data(train_data, all_features, my_output)
simple_feature_matrix, norms = normalize_features(simple_feature_matrix)

# %% [markdown]
# First, learn the weights with `l1_penalty=1e7`, on the training data. Initialize weights to all zeros, and set the `tolerance=1`.  Call resulting weights `weights1e7`, you will need them later.

# %%
initial_weights = np.zeros(14)
print initial_weights.shape
print simple_feature_matrix.shape
print output.shape

l1_penalty = 1e7
tolerance = 1.0

weights = lasso_cyclical_coordinate_descent(simple_feature_matrix, output,
                                           initial_weights, l1_penalty, tolerance)
#prediction = predict_output(simple_feature_matrix,weights)
#error = prediction - output
#RSS = (error*error).sum()
#print RSS
#weights
# Out:
# (14L,)
# (17384L, 14L)
# (17384L,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-f3547ac012eb> in <module>()
#       8
#       9 weights = lasso_cyclical_coordinate_descent(simple_feature_matrix, output,
# ---> 10                                            initial_weights, l1_penalty, tolerance)
#      11 #prediction = predict_output(simple_feature_matrix,weights)
#      12 #error = prediction - output
#
# <ipython-input-28-2a0bb5066114> in lasso_cyclical_coordinate_descent(feature_matrix, output, initial_weights, l1_penalty, tolerance)
#       2     old_weights=initial_weights
#       3     for i in range(len(initial_weights)):
# ----> 4         weights[i] = lasso_coordinate_descent_step(i,feature_matrix,output,old_weights,l1_penalty)
#       5         change=old_weights[i]-weights[i]
#       6
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# ***QUIZ QUESTION***
#
# What features had non-zero weight in this case?

# %% [markdown]
# Next, learn the weights with `l1_penalty=1e8`, on the training data. Initialize weights to all zeros, and set the `tolerance=1`.  Call resulting weights `weights1e8`, you will need them later.

# %% [markdown]
# ***QUIZ QUESTION***
#
# What features had non-zero weight in this case?

# %% [markdown]
# Finally, learn the weights with `l1_penalty=1e4`, on the training data. Initialize weights to all zeros, and set the `tolerance=5e5`.  Call resulting weights `weights1e4`, you will need them later.  (This case will take quite a bit longer to converge than the others above.)

# %% [markdown]
# ***QUIZ QUESTION***
#
# What features had non-zero weight in this case?

# %% [markdown]
# ## Rescaling learned weights

# %% [markdown]
# Recall that we normalized our feature matrix, before learning the weights.  To use these weights on a test set, we must normalize the test data in the same way.
#
# Alternatively, we can rescale the learned weights to include the normalization, so we never have to worry about normalizing the test data:
#
# In this case, we must scale the resulting weights so that we can make predictions with *original* features:
#  1. Store the norms of the original features to a vector called `norms`:
# ```
# features, norms = normalize_features(features)
# ```
#  2. Run Lasso on the normalized features and obtain a `weights` vector
#  3. Compute the weights for the original features by performing element-wise division, i.e.
# ```
# weights_normalized = weights / norms
# ```
# Now, we can apply `weights_normalized` to the test data, without normalizing it!

# %% [markdown]
# Create a normalized version of each of the weights learned above. (`weights1e4`, `weights1e7`, `weights1e8`).

# %% [markdown]
# To check your results, if you call `normalized_weights1e7` the normalized version of `weights1e7`, then:
# ```
# print normalized_weights1e7[3]
# ```
# should return 161.31745624837794.

# %% [markdown]
# ## Evaluating each of the learned models on the test data

# %% [markdown]
# Let's now evaluate the three models on the test data:

# %%
(test_feature_matrix, test_output) = get_numpy_data(test_data, all_features, 'price')

# %% [markdown]
# Compute the RSS of each of the three normalized weights on the (unnormalized) `test_feature_matrix`:

# %% [markdown]
# ***QUIZ QUESTION***
#
# Which model performed best on the test data?
